# %%
from nba.src.statvu_align.entities.clip_dataset import FilteredClipDataset
from nba.src.statvu_align.entities.clip_annotations import ClipAnnotationWrapper

# %%
ex_fp = FilteredClipDataset("/mnt/mir/levlevi/nba-plus-statvu-dataset/filtered-clip-annotations-40-bbx-ratios").filtered_clip_annotations_file_paths[0]
ex_fp

# %%
import pickle

with open(ex_fp, "rb") as f:
    ann = pickle.load(f)

# %%
ann['frames'][0]['bbox'][0]
# Out:
# {'frame_number': 0,
#  'player_id': 23512,
#  'x': 2.1,
#  'y': 435.2,
#  'width': 104.4,
#  'height': 193.3,
#  'confidence': 0.9599999785423279,
#  'keypoints': array([[ 1.14806671e+01,  4.19137115e+01,  3.48388672e-01],
#         [ 7.02703094e+00,  4.55344543e+01,  3.14208984e-01],
#         [ 8.39584656e+01,  3.95744019e+01,  3.28369141e-01],
#         [ 9.02429199e+00,  4.73225327e+01,  3.37402344e-01],
#         [ 1.23809509e+01,  3.42978668e+01,  2.55615234e-01],
#         [ 4.40392380e+01,  4.65370636e+01,  3.35693359e-01],
#         [ 2.70213699e+01,  2.81334572e+01,  2.96142578e-01],
#         [ 5.40212021e+01,  5.27466125e+01,  1.81274414e-01],
#         [ 8.25396729e+00,  2.63829803e+00,  2.26074219e-01],
#         [ 3.33941803e+01,  4.52559738e+01,  7.08007812e-02],
#         [ 6.80952454e+01,  1.18723412e+01,  1.77490234e-01],
#         [ 8.15753174e+01,  4.04221649e+01,  2.07153320e-01],
#         [ 8.08504486e+01,  1.86433220e+01,  2.39624023e-01],
# ...
